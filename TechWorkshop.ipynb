# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# downloads the data from google drive
# !wget -O data.csv "https://drive.google.com/uc?export=download&id=17zbqonizGGegzRu3A6aaYDo00evwDLsA"
# !wget -O predicted_true.json "https://drive.google.com/uc?export=download&id=1AjeXcwYo_wLQaoRbZwcKfayg_irEY9vP"
# !wget -O challenge.csv "https://drive.google.com/uc?export=download&id=1bF8P-vdhBFc4fnNDXs4mYxTymkworkRh"
# Out:
# --2023-10-26 17:31:31--  https://drive.google.com/uc?export=download&id=17zbqonizGGegzRu3A6aaYDo00evwDLsA
# Resolving drive.google.com (drive.google.com)... 173.194.211.139, 173.194.211.113, 173.194.211.101, ...
# Connecting to drive.google.com (drive.google.com)|173.194.211.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9ia18cbrv8580vfhednftbqatnm0sfh3/1698341475000/07682468669272306143/*/17zbqonizGGegzRu3A6aaYDo00evwDLsA?e=download&uuid=fb03be7a-5ab2-4fee-a5f9-47012487c2f1 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-26 17:31:32--  https://doc-0c-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9ia18cbrv8580vfhednftbqatnm0sfh3/1698341475000/07682468669272306143/*/17zbqonizGGegzRu3A6aaYDo00evwDLsA?e=download&uuid=fb03be7a-5ab2-4fee-a5f9-47012487c2f1
# Resolving doc-0c-1c-docs.googleusercontent.com (doc-0c-1c-docs.googleusercontent.com)... 74.125.134.132, 2607:f8b0:400c:c00::84
# Connecting to doc-0c-1c-docs.googleusercontent.com (doc-0c-1c-docs.googleusercontent.com)|74.125.134.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3465438 (3.3M) [text/csv]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>]   3.30M  --.-KB/s    in 0.02s
#
# 2023-10-26 17:31:32 (159 MB/s) - ‘data.csv’ saved [3465438/3465438]
#
# --2023-10-26 17:31:32--  https://drive.google.com/uc?export=download&id=1AjeXcwYo_wLQaoRbZwcKfayg_irEY9vP
# Resolving drive.google.com (drive.google.com)... 173.194.211.139, 173.194.211.113, 173.194.211.101, ...
# Connecting to drive.google.com (drive.google.com)|173.194.211.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/afo886qmh88aoiflrcmpi8aojuvre04i/1698341475000/07682468669272306143/*/1AjeXcwYo_wLQaoRbZwcKfayg_irEY9vP?e=download&uuid=bd4d5e02-7aec-4231-896b-a25fa73ea7a2 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-26 17:31:32--  https://doc-14-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/afo886qmh88aoiflrcmpi8aojuvre04i/1698341475000/07682468669272306143/*/1AjeXcwYo_wLQaoRbZwcKfayg_irEY9vP?e=download&uuid=bd4d5e02-7aec-4231-896b-a25fa73ea7a2
# Resolving doc-14-1c-docs.googleusercontent.com (doc-14-1c-docs.googleusercontent.com)... 74.125.134.132, 2607:f8b0:400c:c00::84
# Connecting to doc-14-1c-docs.googleusercontent.com (doc-14-1c-docs.googleusercontent.com)|74.125.134.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2921 (2.9K) [application/octet-stream]
# Saving to: ‘predicted_true.json’
#
# predicted_true.json 100%[===================>]   2.85K  --.-KB/s    in 0s
#
# 2023-10-26 17:31:32 (144 MB/s) - ‘predicted_true.json’ saved [2921/2921]
#
# --2023-10-26 17:31:32--  https://drive.google.com/uc?export=download&id=1bF8P-vdhBFc4fnNDXs4mYxTymkworkRh
# Resolving drive.google.com (drive.google.com)... 173.194.211.139, 173.194.211.113, 173.194.211.101, ...
# Connecting to drive.google.com (drive.google.com)|173.194.211.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-10-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pgvn2hu6l0r8liaoo3u19g5jh5i05u2c/1698341475000/07682468669272306143/*/1bF8P-vdhBFc4fnNDXs4mYxTymkworkRh?e=download&uuid=d890fc56-9245-4fc4-aaac-59b8e10fbff5 [following]
# Warning: wildcards not supported in HTTP.
# --2023-10-26 17:31:32--  https://doc-10-1c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pgvn2hu6l0r8liaoo3u19g5jh5i05u2c/1698341475000/07682468669272306143/*/1bF8P-vdhBFc4fnNDXs4mYxTymkworkRh?e=download&uuid=d890fc56-9245-4fc4-aaac-59b8e10fbff5
# Resolving doc-10-1c-docs.googleusercontent.com (doc-10-1c-docs.googleusercontent.com)... 74.125.134.132, 2607:f8b0:400c:c00::84
# Connecting to doc-10-1c-docs.googleusercontent.com (doc-10-1c-docs.googleusercontent.com)|74.125.134.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 293 [text/csv]
# Saving to: ‘challenge.csv’
#
# challenge.csv       100%[===================>]     293  --.-KB/s    in 0s
#
# 2023-10-26 17:31:32 (15.9 MB/s) - ‘challenge.csv’ saved [293/293]

# %%
# line graph

# data
x = [1, 2, 3, 4, 5]
y = [2, 4, -1, -2, 3]

# labels
plt.title("Line Graph")
plt.xlabel("x")
plt.ylabel("y")

# graph
plt.plot(x, y, "-o")

# customizations
# differnt markers
# plt.plot(x, y, "-x")
# plt.plot(x, y, "-*")
# plt.plot(x, y, "-v")
# different line styles
# plt.plot(x, y, linestyle="--")
# plt.plot(x, y, linestyle="-.")
# plt.plot(x, y, linestyle=":")

plt.show()

# %%
# bar graph

# data
x = ["lettuce", "tomato", "eggplant", "carrot", "onion"]
y = [10, 21, 69, 100, 57]

# labels
plt.title("Bar Graph")
plt.xlabel("Vegetables")
plt.ylabel("Some Number")

# graph
plt.bar(x, y)
# different colors
# plt.bar(x, y, color="pink")
# plt.bar(x, y, color="green")
# plt.bar(x, y, color="orange")

# customizations
# plt.ylim(0, 500)
# plt.yticks([0, 25, 50, 75, 100, 125, 150])
# plt.yticks([0, 50, 100, 150])
# plt.grid(axis="y")

plt.show()

# %%
# pie chart

# data
pyramid = ["sky", "sunny_side", "shady_side"]
percentages = [75, 17.5, 7.5]
colors = ["skyblue", "wheat", "darkgoldenrod"]

# labels
plt.title("Pie Chart")


# graph
plt.pie(percentages, labels=pyramid, colors=colors, autopct='%1.1f%%', startangle=315)

# customizations
# plt.legend(loc="upper right")
# explode = [0, 0, 0.2]
# plt.pie(percentages, labels=pyramid, colors=colors, autopct='%1.1f%%', startangle=315, explode=explode)

plt.show()

# %%
# training data
data = pd.read_csv("data.csv")

# %%
# getting data
# data["bid_price"]
# data.query("stock_id == 0")
# data.query("stock_id < 3")
# data.query("stock_id == 0")["imbalance_size"]
# pd.DataFrame(data.query("stock_id == 0")["imbalance_size"])
# data[["imbalance_size", "bid_price", "bid_size"]]
# Out:
#        imbalance_size  bid_price  bid_size
# 0          3180602.69   0.999812  60651.50
# 1           166603.91   0.999896   3233.04
# 2           302879.87   0.999403  37956.00
# 3         11917682.27   0.999999   2324.90
# 4           447549.96   0.999394  16485.54
# ...               ...        ...       ...
# 29994      2505110.94   1.001051  11053.06
# 29995      1821215.92   0.995404   8334.92
# 29996       249884.24   0.996717  25445.01
# 29997            0.00   0.997554   9851.92
# 29998      4588556.28   1.006566  44015.40
#
# [29999 rows x 3 columns]

# %%
# seconds vs. imbalance

# data of stock_id == 0
seconds_0 = sorted(data.query("stock_id == 0")["seconds_in_bucket"])
imbalance_0 = data.query("stock_id == 0")["imbalance_size"]

# plt.figure(figsize=(12, 5)) # must do at at beginning

# labels
plt.title("Seconds vs. Imbalance of Stock 0")

# graph
plt.plot(seconds_0, imbalance_0)

# customizations

plt.show()

# %%
# data
x = np.arange(0, 191)
y = data.query("date_id == 0 & seconds_in_bucket == 0")["bid_size"]

plt.figure(figsize=(12, 5))

# labels
plt.title("Bid Size of Each Stock at Time 0")
plt.xlabel("Stock")
plt.ylabel("Bid Size")

# graph
plt.bar(x, y)

plt.show()

# %%
x = data.query("stock_id >= 0 & stock_id < 6")["stock_id"][:10]
y = data.query("stock_id >= 0 & stock_id < 6")["seconds_in_bucket"][::5][:10]
z = data.query("stock_id >= 0 & stock_id < 6")["bid_size"][:100]
# print(x)
# print(y)
# print(z)

fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(121, projection='3d')

xx, yy = np.meshgrid(x, y)
x, y = xx.ravel(), yy.ravel()

top = z
bottom = np.zeros_like(top)
width = 1
depth = 10

ax1.bar3d(x, y, bottom, width, depth, top, shade=True)
ax1.set_title('Shaded')

plt.show()

# %%
# results
results = pd.read_json("predicted_true.json")

# %%
# data
bin_counts = results["data"]["bin_counts"]
bin_averages = results["data"]["bin_averages"]
# this will not work
# lower_bound = results["data"]["bin_averages"] - results["data"]["bin_errors"]
# upper_bound = results["data"]["bin_averages"] + results["data"]["bin_errors"]
# convert to numpy array to perform arithmetic on each value in list
lower_bound = np.array(results["data"]["bin_averages"]) - np.array(results["data"]["bin_errors"])
upper_bound = np.array(results["data"]["bin_averages"]) + np.array(results["data"]["bin_errors"])

# set size of figure
plt.figure(figsize=(12, 5))

# allows for subplots
fig, ax1 = plt.subplots(figsize=(12, 5))

# line graph
# dark blue line
ax1.plot(bin_averages)
# light blue area around
ax1.plot(lower_bound, color="paleturquoise")
ax1.plot(upper_bound, color="paleturquoise")
# y-axis
ax1.set_ylim(-60, 60)
ax1.set_yticks(np.arange(-30, 61, 30))
# horizontal gridlines
ax1.grid(axis='y')
# fill area
ax1.fill_between(range(len(bin_counts)), lower_bound, upper_bound, color="paleturquoise")

# allows for two differnt y-axes
ax2 = ax1.twinx()

# bar graph
ax2.bar(range(len(bin_counts)), height=bin_counts)
# y-axis
ax2.set_ylim(0, 961)
ax2.set_yticks(np.arange(0, 241, 80))
# horizontal gridlines
ax2.grid(axis='y')

# labels
ax1.set_title("Predicted vs. True")
ax1.set_xlabel("True Values")
ax1.set_ylabel("Predicted Values")
ax2.set_ylabel("Bin Counts")
ax2.yaxis.set_label_coords(1.05, 0.125)

# saving graph
# plt.savefig('testing.png')

plt.show()

# %%
# challenge activity
# read csv file "challenge.csv" to get x and y values
# set figure size to (12, 5)
# x lim is from 0 to 100
# y lim is from 0 to 50
# graph scatter plot using x and y values (hint: plt.scatter(x, y))
# set title to what the graph depicts
# first one to get it gets prize
